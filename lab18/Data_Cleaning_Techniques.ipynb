# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data_Cleaning_Techniques

# %%
df = pd.read_csv('./raw_data.csv', header=None)
df.columns = ['user_name', 'age', 'town']
df
# Out:
#   user_name   age     town
# 0      Ivan  34.0    Sofia
# 1     Maria  28.0  Plovdiv
# 2     Maria   NaN  Plovdiv
# 3      Ivan  34.0      NaN
# 4     Maria   NaN  Plovdiv
# 5     Maria   NaN  Plovdiv
# 6      Ivan  34.0    Sofia
# 7     Maria  28.0  Plovdiv
# 8    Georgi  45.0    Varna

# %%
# replace all town NaN with Sofia:
# df.town.fillna(value='SOFIA')
df.fillna(value={'town':'SOFIA', 'age': df.age.median()})
# Out:
#   user_name   age     town
# 0      Ivan  34.0    Sofia
# 1     Maria  28.0  Plovdiv
# 2     Maria  34.0  Plovdiv
# 3      Ivan  34.0    SOFIA
# 4     Maria  34.0  Plovdiv
# 5     Maria  34.0  Plovdiv
# 6      Ivan  34.0    Sofia
# 7     Maria  28.0  Plovdiv
# 8    Georgi  45.0    Varna

# %%
df
# Out:
#   user_name   age     town
# 0      Ivan  34.0    Sofia
# 1     Maria  28.0  Plovdiv
# 2     Maria   NaN  Plovdiv
# 3      Ivan  34.0      NaN
# 4     Maria   NaN  Plovdiv
# 5     Maria   NaN  Plovdiv
# 6      Ivan  34.0    Sofia
# 7     Maria  28.0  Plovdiv
# 8    Georgi  45.0    Varna

# %%
df.bfill()
# Out:
#   user_name   age     town
# 0      Ivan  34.0    Sofia
# 1     Maria  28.0  Plovdiv
# 2     Maria  34.0  Plovdiv
# 3      Ivan  34.0  Plovdiv
# 4     Maria  34.0  Plovdiv
# 5     Maria  34.0  Plovdiv
# 6      Ivan  34.0    Sofia
# 7     Maria  28.0  Plovdiv
# 8    Georgi  45.0    Varna

# %%
df
# Out:
#   user_name   age     town
# 0      Ivan  34.0    Sofia
# 1     Maria  28.0  Plovdiv
# 2     Maria   NaN  Plovdiv
# 3      Ivan  34.0      NaN
# 4     Maria   NaN  Plovdiv
# 5     Maria   NaN  Plovdiv
# 6      Ivan  34.0    Sofia
# 7     Maria  28.0  Plovdiv
# 8    Georgi  45.0    Varna

# %%
df.loc[3,:] = np.NaN
df
# Out:
#   user_name   age     town
# 0      Ivan  34.0    Sofia
# 1     Maria  28.0  Plovdiv
# 2     Maria   NaN  Plovdiv
# 3       NaN   NaN      NaN
# 4     Maria   NaN  Plovdiv
# 5     Maria   NaN  Plovdiv
# 6      Ivan  34.0    Sofia
# 7     Maria  28.0  Plovdiv
# 8    Georgi  45.0    Varna

# %%
df.dropna(axis=1, how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
df
# Out:
#   user_name   age     town
# 0      Ivan  34.0    Sofia
# 1     Maria  28.0  Plovdiv
# 2     Maria   NaN  Plovdiv
# 3       NaN   NaN      NaN
# 4     Maria   NaN  Plovdiv
# 5     Maria   NaN  Plovdiv
# 6      Ivan  34.0    Sofia
# 7     Maria  28.0  Plovdiv
# 8    Georgi  45.0    Varna

# %%
df.loc[4,'town'] = 'Burgas'
df
# Out:
#   user_name   age     town
# 0      Ivan  34.0    Sofia
# 1     Maria  28.0  Plovdiv
# 2     Maria   NaN  Plovdiv
# 3       NaN   NaN      NaN
# 4     Maria   NaN   Burgas
# 5     Maria   NaN  Plovdiv
# 6      Ivan  34.0    Sofia
# 7     Maria  28.0  Plovdiv
# 8    Georgi  45.0    Varna

# %%
df.drop_duplicates(subset='user_name', keep='first')
# Out:
#   user_name   age     town
# 0      Ivan  34.0    Sofia
# 1     Maria  28.0  Plovdiv
# 3       NaN   NaN      NaN
# 8    Georgi  45.0    Varna

# %%
df
# Out:
#   user_name   age     town
# 0      Ivan  34.0    Sofia
# 1     Maria  28.0  Plovdiv
# 2     Maria   NaN  Plovdiv
# 3       NaN   NaN      NaN
# 4     Maria   NaN   Burgas
# 5     Maria   NaN  Plovdiv
# 6      Ivan  34.0    Sofia
# 7     Maria  28.0  Plovdiv
# 8    Georgi  45.0    Varna

# %%
df.replace(to_replace=['Ivan', 'Maria'], value=['11111', '2222'] )
# Out:
#   user_name   age     town
# 0     11111  34.0    Sofia
# 1      2222  28.0  Plovdiv
# 2      2222   NaN  Plovdiv
# 3       NaN   NaN      NaN
# 4      2222   NaN   Burgas
# 5      2222   NaN  Plovdiv
# 6     11111  34.0    Sofia
# 7      2222  28.0  Plovdiv
# 8    Georgi  45.0    Varna

# %%
df
# Out:
#   user_name   age     town
# 0      Ivan  34.0    Sofia
# 1     Maria  28.0  Plovdiv
# 2     Maria   NaN  Plovdiv
# 3       NaN   NaN      NaN
# 4     Maria   NaN   Burgas
# 5     Maria   NaN  Plovdiv
# 6      Ivan  34.0    Sofia
# 7     Maria  28.0  Plovdiv
# 8    Georgi  45.0    Varna

# %%
df.iloc[7, [0,2]] = df.iloc[7, [0,2]]+'   __'

# %%
# 'Maria __' => '$1'
# TODO: DONE
df.replace(to_replace=r'^(\w+).*$', value=r'\1', regex=True)
# Out:
#   user_name   age     town
# 0      Ivan  34.0    Sofia
# 1     Maria  28.0  Plovdiv
# 2     Maria   NaN  Plovdiv
# 3       NaN   NaN      NaN
# 4     Maria   NaN   Burgas
# 5     Maria   NaN  Plovdiv
# 6      Ivan  34.0    Sofia
# 7     Maria  28.0  Plovdiv
# 8    Georgi  45.0    Varna

# %%
# dataset of transaction amounts with less extreme outliers
data = {
    'transaction_amount': [
        # Main data cluster
        49, 51, 50, 50, 51, 52, 48, 49, 50, 51, 50, 49, 52, 48, 50, 51, 49, 50, 51, 52,
        48, 50, 49, 51, 52, 49, 50, 51, 48, 52, 50, 49, 51, 50, 52, 48, 50, 51, 49, 50,
        51, 52, 48, 50, 49, 51, 52, 49, 50, 51, 48, 52, 50, 49, 51, 50, 52, 48, 50, 51,
        # outliers
        47, 45, 60, 61, 62, 39
    ]
}

df = pd.DataFrame(data)

# %%
# Plot the data:
plt.figure(figsize=(6, 2))
sns.boxplot(x='transaction_amount', data=df,
            showfliers=True,
            flierprops=dict(marker='o', color='red', markersize=5),
            boxprops=dict(color="skyblue"),
            whiskerprops=dict(color="green"),
            capprops=dict(color="green"),
            medianprops=dict(color="gold"))

plt.title('Transaction Amounts Box Plot')
plt.xlabel('Transaction Amount')
plt.show()
# Out:
# /media/nemsys/data/projects/courses/ProgressBG/ProgressBG-Python-Digitall/ProgressBG-Python-Digitall-Labs/.venv/lib/python3.12/site-packages/seaborn/categorical.py:700: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   artists = ax.bxp(**boxplot_kws)

# %%
# Outlier detection and removal using IQR
Q1 = df['transaction_amount'].quantile(0.25)
Q3 = df['transaction_amount'].quantile(0.75)
IQR = Q3 - Q1
print(f'IQR: {IQR}')

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identifying outliers
outliers = df[(df['transaction_amount'] < lower_bound) | (df['transaction_amount'] > upper_bound)]
print('Outliers:')
print(outliers['transaction_amount'].tolist())

df_filtered = df[(df['transaction_amount'] >= lower_bound) & (df['transaction_amount'] <= upper_bound)]
print(f'Filtered data:')
print(df_filtered['transaction_amount'].tolist())
print(f"Number of outliers removed: {len(df) - len(df_filtered)}")
# Out:
# IQR: 2.0
# Outliers:
# [45, 60, 61, 62, 39]
# Filtered data:
# [49, 51, 50, 50, 51, 52, 48, 49, 50, 51, 50, 49, 52, 48, 50, 51, 49, 50, 51, 52, 48, 50, 49, 51, 52, 49, 50, 51, 48, 52, 50, 49, 51, 50, 52, 48, 50, 51, 49, 50, 51, 52, 48, 50, 49, 51, 52, 49, 50, 51, 48, 52, 50, 49, 51, 50, 52, 48, 50, 51, 47]
# Number of outliers removed: 5

# %%
df = pd.read_csv('https://raw.githubusercontent.com/geekcourses/JupyterNotebooksExamples/master/datasets/various/drinks.csv')
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# ..                            ...       ...
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 6 columns]

# %%
# TASK: find countries which beer_servings > 'Bulgaria' and are from EU

# %%
bg_beer = df.loc[df.country=='Bulgaria', 'beer_servings']
bg_beer = bg_beer.values[0]
bg_beer
# Out:
# 231

# %%
# df.beer_servings>bg_beer
df['continent']=='EU'
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: continent, Length: 193, dtype: bool

# %%
mask = (df.beer_servings>bg_beer) & (df['continent']=='EU')
mask
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Length: 193, dtype: bool

# %%
df.loc[mask,'country']
# Out:
# 3             Andorra
# 9             Austria
# 16            Belgium
# 45     Czech Republic
# 60            Finland
# 65            Germany
# 75            Hungary
# 76            Iceland
# 81            Ireland
# 93             Latvia
# 98          Lithuania
# 99         Luxembourg
# 120       Netherlands
# 135            Poland
# 140           Romania
# 151            Serbia
# 156          Slovenia
# 160             Spain
# Name: country, dtype: object

# %%
# Sample DataFrame with customer profiles
data = {
    'CustomerID': [101, 102, 103, 104, 105],
    'Name': ['Ivan Petrov', 'Maria Ivanova', 'Georgi Dimitrov', 'Ivan Georgiev', 'Maria Ivanova'],
    'Email': ['ivan_petrov@example.com', 'maria_ivanova@example.com', 'georgi_dimitrov@example.com', 'ivan_georgiev@example.com', 'maria_ivanova@example.com']
}

df = pd.DataFrame(data)
df
# Out:
#    CustomerID             Name                        Email
# 0         101      Ivan Petrov      ivan_petrov@example.com
# 1         102    Maria Ivanova    maria_ivanova@example.com
# 2         103  Georgi Dimitrov  georgi_dimitrov@example.com
# 3         104    Ivan Georgiev    ivan_georgiev@example.com
# 4         105    Maria Ivanova    maria_ivanova@example.com

# %%
df.drop_duplicates(subset='Email')
# Out:
#    CustomerID             Name                        Email
# 0         101      Ivan Petrov      ivan_petrov@example.com
# 1         102    Maria Ivanova    maria_ivanova@example.com
# 2         103  Georgi Dimitrov  georgi_dimitrov@example.com
# 3         104    Ivan Georgiev    ivan_georgiev@example.com

# %%
# Sample data with inconsistent date formats
data = {
    'Event': ['Concert', 'Conference', 'Meeting', 'Workshop', 'Seminar'],
    'Date': ['12/05/2024', '05/15/2024', '23/06/2024', '07/20/2024', '10/11/2024']
}

df = pd.DataFrame(data)
df
# Out:
#         Event        Date
# 0     Concert  12/05/2024
# 1  Conference  05/15/2024
# 2     Meeting  23/06/2024
# 3    Workshop  07/20/2024
# 4     Seminar  10/11/2024

# %%
from datetime import datetime

date_str = '05/15/2024'
def standardize_date(date_str):
    try:
        date = datetime.strptime(date_str,'%d/%m/%Y')
        return date.strftime('%Y-%m-%d')
    except:
        try:
            date = datetime.strptime(date_str,'%m/%d/%Y')
            return date.strftime('%Y-%m-%d')
        except:
            return np.NaN

print( standardize_date(date_str) )
# Out:
# 2024-05-15

# %%
df['StandardizedDate'] = df['Date'].apply(standardize_date)
df
# Out:
#         Event        Date StandardizedDate
# 0     Concert  12/05/2024       2024-05-12
# 1  Conference  05/15/2024       2024-05-15
# 2     Meeting  23/06/2024       2024-06-23
# 3    Workshop  07/20/2024       2024-07-20
# 4     Seminar  10/11/2024       2024-11-10

# %%
# Sample data with incorrect values in the 'Years of Experience' field
data = {
    'Employee Name': ['Ivan Ivanov', 'Maria Popova', 'Georgi Georgiev', 'Sofia Petrova', 'Nikolai Nikolov'],
    'Position': ['Software Developer', 'Project Manager', 'Data Analyst', 'UX Designer', 'HR Specialist'],
    'Years of Experience': [5, -2, 25, 3, 150]
}

df = pd.DataFrame(data)
df
# Out:
#      Employee Name            Position  Years of Experience
# 0      Ivan Ivanov  Software Developer                    5
# 1     Maria Popova     Project Manager                   -2
# 2  Georgi Georgiev        Data Analyst                   25
# 3    Sofia Petrova         UX Designer                    3
# 4  Nikolai Nikolov       HR Specialist                  150

# %%
valid_years_mask = (df['Years of Experience']>=0) & (df['Years of Experience']<=50)
df[valid_years_mask]
# Out:
#      Employee Name            Position  Years of Experience
# 0      Ivan Ivanov  Software Developer                    5
# 2  Georgi Georgiev        Data Analyst                   25
# 3    Sofia Petrova         UX Designer                    3

# %%
mean_years = df.loc[valid_years_mask, 'Years of Experience'].mean()
print(f'mean_years = {mean_years}')

median_years = df.loc[valid_years_mask, 'Years of Experience'].median()
print(f'median_years = {median_years}')
# Out:
# mean_years = 11.0
# median_years = 5.0

# %%
# get invalid data
valid_years_mask = (df['Years of Experience']<0) | (df['Years of Experience']>50)
df.loc[valid_years_mask, 'Years of Experience'] = mean_years
df
# Out:
#      Employee Name            Position  Years of Experience
# 0      Ivan Ivanov  Software Developer                    5
# 1     Maria Popova     Project Manager                   11
# 2  Georgi Georgiev        Data Analyst                   25
# 3    Sofia Petrova         UX Designer                    3
# 4  Nikolai Nikolov       HR Specialist                   11
