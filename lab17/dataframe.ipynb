# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Basics

# %%
prices_ds = pd.Series(
    [1.5, 2, 2.5, 3],
    index=["apples", "oranges", "bananas", "strawberries"]
)

suppliers_ds = pd.Series(
    ["supplier1", "supplier2", "supplier4", "supplier3"],
    index=["apples", "oranges", "bananas", "strawberries"]
)

fruits_df = pd.DataFrame({
    "prices": prices_ds,
    "suppliers": suppliers_ds
})

fruits_df
# Out:
#               prices  suppliers
# apples           1.5  supplier1
# oranges          2.0  supplier2
# bananas          2.5  supplier4
# strawberries     3.0  supplier3

# %% [markdown]
# ## Create DataFrame from csv file

# %%
csv_file = 'https://raw.githubusercontent.com/geekcourses/JupyterNotebooksExamples/master/datasets/various/drinks.csv'

drinks = pd.read_csv(csv_file)
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
csv_file = './data.csv'
column_names = ['Name', 'Age', 'City']

data = pd.read_csv(csv_file, header=None, names=column_names, nrows=3)
data
# Out:
#     Name  Age     City
# 0   Ivan   34    Sofia
# 1  Maria   28  Plovdiv
# 2  Maria   28  Plovdiv

# %% [markdown]
# ## Write to Excel

# %%
excel_file = 'drinks.xlsx'
pd.ExcelWriter(excel_file)

# %% [markdown]
# ## Create DF from json

# %%
json_file = 'https://raw.githubusercontent.com/geekcourses/JupyterNotebooksExamples/master/datasets/python_books/books.json'
books = pd.read_json(json_file)
books.head(3)
# Out:
#                                    title       author  \
# 0         How to Make Mistakes in Python  Mike Pirnat
# 1       Functional Programming in Python  David Mertz
# 2  Picking a Python Version: A Manifesto  David Mertz
#
#                                            authorUrl         level
# 0                            http://mike.pirnat.com/  Intermediate
# 1  http://www.oreilly.com/programming/free/functi...  Intermediate
# 2  http://www.oreilly.com/programming/free/from-f...      Beginner

# %%
csv_file = './datasets/books.csv'
books.to_csv(csv_file, index=False)

# %%
books.loc[0,'title'] = 'How to Make,Mistakes in Python'
books
# Out:
#                                                 title                author  \
# 0                      How to Make,Mistakes in Python           Mike Pirnat
# 1                    Functional Programming in Python           David Mertz
# 2               Picking a Python Version: A Manifesto           David Mertz
# 3           Python para Desenvolvedores (2nd Edition)   Luiz Eduardo Borges
# 4                                 Intermediate Python       Muhammad Yasoob
# ..                                                ...                   ...
# 72       Raspberry Pi Cookbook for Python Programmers               Tim Cox
# 73                     Annotated Algorithms In Python     Massimo Di Pierro
# 74                               Python for Everybody  Charles R. Severance
# 75  20 Python libraries You Aren't Using (But Should)        Caleb Hattingh
# 76              Advanced Machine Learning with Python           John Hearty
#
# ...

# %%
import csv

csv_file = './datasets/books.csv'
books.to_csv(csv_file, index=False, quoting=csv.QUOTE_NONNUMERIC, quotechar="'")
