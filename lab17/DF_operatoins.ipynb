# %%
import pandas as pd
import numpy as np

# %%
csv_file = 'https://raw.githubusercontent.com/geekcourses/JupyterNotebooksExamples/master/datasets/various/drinks.csv'

drinks = pd.read_csv(csv_file)
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# drinks['continent']
drinks.continent.head(2)
# Out:
# 0    AS
# 1    EU
# Name: continent, dtype: object

# %%
df = drinks[ ['beer_servings', 'country'] ]
df
# Out:
#      beer_servings      country
# 0                0  Afghanistan
# 1               89      Albania
# 2               25      Algeria
# 3              245      Andorra
# 4              217       Angola
# ..             ...          ...
# 188            333    Venezuela
# 189            111      Vietnam
# 190              6        Yemen
# 191             32       Zambia
# 192             64     Zimbabwe
#
# [193 rows x 2 columns]

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.loc[0:5, 'country']
# Out:
# 0          Afghanistan
# 1              Albania
# 2              Algeria
# 3              Andorra
# 4               Angola
# 5    Antigua & Barbuda
# Name: country, dtype: object

# %%
drinks.iloc[0:5, 0 ]
# Out:
# 0    Afghanistan
# 1        Albania
# 2        Algeria
# 3        Andorra
# 4         Angola
# Name: country, dtype: object

# %%
# drinks.set_index('country', inplace=True)
drinks
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# ...

# %%
# drinks.iloc[:3, [0,2]]
drinks.loc[['Albania', 'Algeria'], ['beer_servings', 'wine_servings']]
# Out:
#          beer_servings  wine_servings
# country
# Albania             89             54
# Algeria             25             14

# %%
drinks
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0        AS
# Albania                               4.9        EU
# Algeria                               0.7        AF
# ...

# %%
mask = drinks['continent'] == 'EU'

# %%
eu_drinks = drinks[mask]
eu_drinks.head(3)
# Out:
#          beer_servings  spirit_servings  wine_servings  \
# country
# Albania             89              132             54
# Andorra            245              138            312
# Armenia             21              179             11
#
#          total_litres_of_pure_alcohol continent
# country
# Albania                           4.9        EU
# Andorra                          12.4        EU
# Armenia                           3.8        EU

# %%
# get all EU countries, for which beer_servings>100
eu_drinks[ eu_drinks['beer_servings']>100 ].head()
# Out:
#           beer_servings  spirit_servings  wine_servings  \
# country
# Andorra             245              138            312
# Austria             279               75            191
# Belarus             142              373             42
# Belgium             295               84            212
# Bulgaria            231              252             94
#
#           total_litres_of_pure_alcohol continent
# country
# Andorra                           12.4        EU
# Austria                            9.7        EU
# Belarus                           14.4        EU
# Belgium                           10.5        EU
# Bulgaria                          10.3        EU
