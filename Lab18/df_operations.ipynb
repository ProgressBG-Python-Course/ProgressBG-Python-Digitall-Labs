# %%
import pandas as pd
import numpy as np

# %%
csv_file = 'https://raw.githubusercontent.com/geekcourses/JupyterNotebooksExamples/master/datasets/various/drinks.csv'
df = pd.read_csv(csv_file)
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
df.shape
# Out:
# (193, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
data_numeric = df.select_dtypes(include=[np.number])
data_numeric.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  total_litres_of_pure_alcohol
# 0              0                0              0                           0.0
# 1             89              132             54                           4.9
# 2             25                0             14                           0.7
# 3            245              138            312                          12.4
# 4            217               57             45                           5.9

# %%
print(f'Max beer: {df.wine_servings.max()}')
print(f'Mean beer: {df.wine_servings.mean()}')
print(f'Median beer: {df.wine_servings.median()}')
# Out:
# Max beer: 370
# Mean beer: 49.45077720207254
# Median beer: 8.0

# %%
data_numeric.max(axis=0)
# Out:
# beer_servings                   376.0
# spirit_servings                 438.0
# wine_servings                   370.0
# total_litres_of_pure_alcohol     14.4
# dtype: float64

# %%
data_numeric.idxmax()
# Out:
# beer_servings                   117
# spirit_servings                  68
# wine_servings                    61
# total_litres_of_pure_alcohol     15
# dtype: int64

# %%
df[df.wine_servings==370]
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 61  France            127              151            370
#
#     total_litres_of_pure_alcohol continent
# 61                          11.8        EU

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# TASK: find max beer_servings in all continents
df.loc[df.continent=='EU',:].max()
# df.loc[df.continent=='AS','beer_servings'].max()
# Out:
# country                         United Kingdom
# beer_servings                              361
# spirit_servings                            373
# wine_servings                              370
# total_litres_of_pure_alcohol              14.4
# continent                                   EU
# dtype: object

# %%
df.groupby(by='continent').max()
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# continent
# AF               Zimbabwe            376              152            233
# AS                  Yemen            247              326            123
# EU         United Kingdom            361              373            370
# OC                Vanuatu            306              254            212
# SA              Venezuela            333              302            221
#
#            total_litres_of_pure_alcohol
# continent
# AF                                  9.1
# AS                                 11.5
# EU                                 14.4
# OC                                 10.4
# SA                                  8.3

# %%
bg_weather_df = pd.DataFrame({
  "town": ["Sofia", "Sandanski", "Pleven"],
  "temp":[25,32,21],
  "rain": [False, False, True ]
})
bg_weather_df
# Out:
#         town  temp   rain
# 0      Sofia    25  False
# 1  Sandanski    32  False
# 2     Pleven    21   True

# %%
eu_weather_df = pd.DataFrame({
  "town": ["Atina", "Oslo", "London"],
  "temp":[35,21,25],
  "rain": [False, False, True ]
})
eu_weather_df
# Out:
#      town  temp   rain
# 0   Atina    35  False
# 1    Oslo    21  False
# 2  London    25   True

# %%
# bg_weather_df.insert(loc=1, column='wind', value=[10, 8, 11])
bg_weather_df
# Out:
#         town  wind  temp   rain
# 0      Sofia    10    25  False
# 1  Sandanski     8    32  False
# 2     Pleven    11    21   True

# %%
# bg_weather_df.drop(labels='wind', axis=1)
bg_weather_df.drop(columns='wind')
# Out:
#         town  temp   rain
# 0      Sofia    25  False
# 1  Sandanski    32  False
# 2     Pleven    21   True

# %%
bg_weather_df.drop(index=1)
# Out:
#      town  wind  temp   rain
# 0   Sofia    10    25  False
# 2  Pleven    11    21   True

# %%
# bg_weather_df = bg_weather_df.drop(columns='wind')
bg_weather_df
# Out:
#         town  temp   rain
# 0      Sofia    25  False
# 1  Sandanski    32  False
# 2     Pleven    21   True

# %%
eu_weather_df
# Out:
#      town  temp   rain
# 0   Atina    35  False
# 1    Oslo    21  False
# 2  London    25   True

# %%
appended_weather = pd.concat([bg_weather_df, eu_weather_df], ignore_index=True)
appended_weather
# Out:
#         town  temp   rain
# 0      Sofia    25  False
# 1  Sandanski    32  False
# 2     Pleven    21   True
# 3      Atina    35  False
# 4       Oslo    21  False
# 5     London    25   True

# %%
appended_weather = pd.concat([bg_weather_df, eu_weather_df], axis=1, ignore_index=True)
appended_weather
# Out:
#            0   1      2       3   4      5
# 0      Sofia  25  False   Atina  35  False
# 1  Sandanski  32  False    Oslo  21  False
# 2     Pleven  21   True  London  25   True
